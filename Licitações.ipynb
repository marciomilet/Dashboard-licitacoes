# %% [markdown]
# <a href="https://colab.research.google.com/github/marciomilet/Dashboard-licitacoes/blob/main/Licita%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importa as bibliotecas faz uma requisição do dataset e define o encoding para utf-8 case não consiga executar a requisição retorna um erro

# %%
import pandas as pd
import requests as req
from io import StringIO
import urllib
from sklearn.preprocessing import LabelEncoder


url =  "http://dados.recife.pe.gov.br/dataset/591a6ed4-7beb-4304-a2a1-2af521517a06/resource/c5d7505c-381c-4670-a0c2-1fbf56df50b1/download/dados_abertos_licitacao_concluida.csv"

try:
    response = req.get(url)
    response.encoding = 'utf-8'
    response.raise_for_status()  # Lança um erro para respostas não-sucedidas
    # Usando StringIO para converter o texto em um arquivo em memória e, então, lendo com o Pandas
    csv_raw = StringIO(response.text)
    base = pd.read_csv(csv_raw, sep=';', encoding='utf-8')



except req.RequestException as e:
    print(f"Erro ao acessar o arquivo: {e}")

# %% [markdown]
# # Lê o cabeçalho

# %%
base.head(3)
# Out:
#                                   comissao_licitacao  ano_processolicitatorio  \
# 0  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
# 1  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
# 2  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
#
#    num_processolicitatorio  numero_lote modalidadeprocessolicitatorio  \
# 0                       29            1             PREGÃO ELETRÔNICO
# 1                       29            2             PREGÃO ELETRÔNICO
# 2                       30            1             PREGÃO ELETRÔNICO
#
#    numerolicitacaomodalidade  anolicitacaomodalidade         orgao_licitante  \
# 0                         27                    2012  SECRETARIA DE EDUCAÇÃO
# 1                         27                    2012  SECRETARIA DE EDUCAÇÃO
# 2                         28                    2012  SECRETARIA DE EDUCAÇÃO
#
#                 objeto  cnpj_contratado  ...  num_endcontratado  \
# 0     MATERIAL GRÁFICO     7.586060e+11  ...              301.0
# 1     MATERIAL GRÁFICO     7.211171e+12  ...             5327.0
# 2  AGENDA ESCOLAR 2013     1.389899e+13  ...                0.0
#
#   comp_endcontratado  bairro_endcontratado     cidade_endcontratado  \
# 0                NaN              BULTRINS                   OLINDA
# 1                NaN              CANDEIAS  JABOATAO DOS GUARARAPES
# 2           LOJA 005  CIDADE UNIVERSITARIA                   MACEIO
#
#   uf_endcontratado valor_total_estimado valor_totalhomologadolicitacao  \
# 0               PE            333750,00                       66358,00
# 1               PE            333750,00                       66358,00
# 2               AL            530469,54                      357895,02
#
#     valor_licitacao_lote    data_aberturaproposta  data_ultimafaseprocesso
# 0               15210,00  2012/12/20 10:00:00.000  2013/01/07 00:00:00.000
# 1               51148,00  2012/12/20 10:00:00.000  2013/01/07 00:00:00.000
# 2              357895,02  2013/01/02 10:00:00.000  2013/01/09 00:00:00.000
#
# [3 rows x 23 columns]

# %% [markdown]
# # Informações da base

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19108 entries, 0 to 19107
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   comissao_licitacao              19108 non-null  object
#  1   ano_processolicitatorio         19108 non-null  int64
#  2   num_processolicitatorio         19108 non-null  int64
#  3   numero_lote                     19108 non-null  int64
#  4   modalidadeprocessolicitatorio   19108 non-null  object
#  5   numerolicitacaomodalidade       19108 non-null  int64
#  6   anolicitacaomodalidade          19108 non-null  int64
#  7   orgao_licitante                 19108 non-null  object
#  8   objeto                          19108 non-null  object
#  9   cnpj_contratado                 19092 non-null  float64
#  10  cpf_contratado                  16 non-null     float64
#  11  razao_nomecontratado            19108 non-null  object
#  12  logradouro_endcontratado        19096 non-null  object
#  13  num_endcontratado               17551 non-null  float64
#  14  comp_endcontratado              9869 non-null   object
#  15  bairro_endcontratado            19070 non-null  object
#  16  cidade_endcontratado            19096 non-null  object
#  17  uf_endcontratado                19079 non-null  object
#  18  valor_total_estimado            19108 non-null  object
#  19  valor_totalhomologadolicitacao  19018 non-null  object
#  20  valor_licitacao_lote            19108 non-null  object
#  21  data_aberturaproposta           19108 non-null  object
#  22  data_ultimafaseprocesso         19108 non-null  object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 3.4+ MB

# %% [markdown]
# # Corrigindo tipos das tabelas

# %%
base.num_endcontratado.dtypes
# Out:
# dtype('float64')

# %%
base.data_ultimafaseprocesso.dtypes
# Out:
# dtype('O')

# %%
base.data_aberturaproposta.dtypes
# Out:
# dtype('O')

# %%
base.cpf_contratado.dtypes
# Out:
# dtype('float64')

# %%
base['num_endcontratado'] = base['num_endcontratado'].round().astype('object')

# %%
base['cpf_contratado'] = base['cpf_contratado'].astype('object')
base['cnpj_contratado'] = base['cnpj_contratado'].astype('object')

# %%
base['data_ultimafaseprocesso'] = pd.to_datetime(base['data_ultimafaseprocesso'])
base['data_aberturaproposta'] = pd.to_datetime(base['data_aberturaproposta'])

# %% [markdown]
# # Valores nulos

# %%
base.isnull().sum()
# Out:
# comissao_licitacao                    0
# ano_processolicitatorio               0
# num_processolicitatorio               0
# numero_lote                           0
# modalidadeprocessolicitatorio         0
# numerolicitacaomodalidade             0
# anolicitacaomodalidade                0
# orgao_licitante                       0
# objeto                                0
# cnpj_contratado                      16
# cpf_contratado                    19092
# razao_nomecontratado                  0
# logradouro_endcontratado             12
# num_endcontratado                  1557
# comp_endcontratado                 9239
# bairro_endcontratado                 38
# cidade_endcontratado                 12
# uf_endcontratado                     29
# valor_total_estimado                  0
# valor_totalhomologadolicitacao       90
# valor_licitacao_lote                  0
# data_aberturaproposta                 0
# data_ultimafaseprocesso               0
# dtype: int64

# %%
base.isna().sum()
# Out:
# comissao_licitacao                    0
# ano_processolicitatorio               0
# num_processolicitatorio               0
# numero_lote                           0
# modalidadeprocessolicitatorio         0
# numerolicitacaomodalidade             0
# anolicitacaomodalidade                0
# orgao_licitante                       0
# objeto                                0
# cnpj_contratado                      16
# cpf_contratado                    19092
# razao_nomecontratado                  0
# logradouro_endcontratado             12
# num_endcontratado                  1557
# comp_endcontratado                 9239
# bairro_endcontratado                 38
# cidade_endcontratado                 12
# uf_endcontratado                     29
# valor_total_estimado                  0
# valor_totalhomologadolicitacao       90
# valor_licitacao_lote                  0
# data_aberturaproposta                 0
# data_ultimafaseprocesso               0
# dtype: int64

# %%
base.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19103    False
# 19104    False
# 19105    False
# 19106    False
# 19107    False
# Length: 19108, dtype: bool

# %% [markdown]
# # corrigindo valores nulos nos endereços

# %%
base[base.logradouro_endcontratado.isnull()]
# Out:
#                                       comissao_licitacao  \
# 984    COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 985    COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 4161   COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 11923                          EQUIPE DE PREGÃO - EMLURB
# 11927                          EQUIPE DE PREGÃO - EMLURB
# 11929                          EQUIPE DE PREGÃO - EMLURB
# 11932                          EQUIPE DE PREGÃO - EMLURB
# 11933                          EQUIPE DE PREGÃO - EMLURB
# 11934                          EQUIPE DE PREGÃO - EMLURB
# 11936                          EQUIPE DE PREGÃO - EMLURB
# 11938                          EQUIPE DE PREGÃO - EMLURB
# 11939                          EQUIPE DE PREGÃO - EMLURB
#
#        ano_processolicitatorio  num_processolicitatorio  numero_lote  \
# 984                       2013                       15            1
# 985                       2013                       15            2
# 4161                      2015                       17            2
# 11923                     2020                        2            4
# 11927                     2020                        2            8
# 11929                     2020                        2           10
# 11932                     2020                        2           13
# 11933                     2020                        2           14
# 11934                     2020                        2           15
# 11936                     2020                        2           17
# 11938                     2020                        2           19
# 11939                     2020                        2           20
#
#       modalidadeprocessolicitatorio  numerolicitacaomodalidade  \
# 984               PREGÃO ELETRÔNICO                         12
# 985               PREGÃO ELETRÔNICO                         12
# 4161              PREGÃO ELETRÔNICO                         12
# 11923             PREGÃO ELETRÔNICO                          2
# 11927             PREGÃO ELETRÔNICO                          2
# 11929             PREGÃO ELETRÔNICO                          2
# 11932             PREGÃO ELETRÔNICO                          2
# 11933             PREGÃO ELETRÔNICO                          2
# 11934             PREGÃO ELETRÔNICO                          2
# 11936             PREGÃO ELETRÔNICO                          2
# 11938             PREGÃO ELETRÔNICO                          2
# 11939             PREGÃO ELETRÔNICO                          2
#
#        anolicitacaomodalidade  \
# 984                      2013
# 985                      2013
# 4161                     2015
# 11923                    2020
# 11927                    2020
# 11929                    2020
# 11932                    2020
# 11933                    2020
# 11934                    2020
# 11936                    2020
# 11938                    2020
# 11939                    2020
#
#                                          orgao_licitante  \
# 984                             FUNDO MUNICIPAL DE SAUDE
# 985                             FUNDO MUNICIPAL DE SAUDE
# 4161                            FUNDO MUNICIPAL DE SAUDE
# 11923  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11927  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11929  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11932  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11933  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11934  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11936  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11938  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11939  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
#
#                                                   objeto   cnpj_contratado  \
# 984    AQUISIÇÃO DE TESTE HEMATOLÓGICOS BIOQUÍMICOS, ...  42160812000144.0
# 985    AQUISIÇÃO DE TESTE HEMATOLÓGICOS BIOQUÍMICOS, ...  42160812000144.0
# 4161   REGISTRO DE PREÇOS PARA AQUISIÇÃO DE GRUPOS GE...  92753268005262.0
# 11923  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11927  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11929  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11932  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11933  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11934  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11936  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11938  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11939  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
#
#        ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 984    ...               NaN                NaN                  NaN
# 985    ...               NaN                NaN                  NaN
# 4161   ...               NaN                NaN                  NaN
# 11923  ...             699.0            BLOCO A                  NaN
# 11927  ...             699.0            BLOCO A                  NaN
# 11929  ...             699.0            BLOCO A                  NaN
# 11932  ...             699.0            BLOCO A                  NaN
# 11933  ...             699.0            BLOCO A                  NaN
# 11934  ...             699.0            BLOCO A                  NaN
# 11936  ...             699.0            BLOCO A                  NaN
# 11938  ...             699.0            BLOCO A                  NaN
# 11939  ...             699.0            BLOCO A                  NaN
#
#       cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 984                    NaN              NaN           9207876,50
# 985                    NaN              NaN           9207876,50
# 4161                   NaN              NaN           2930322,00
# 11923                  NaN              NaN          20830169,37
# 11927                  NaN              NaN          20830169,37
# 11929                  NaN              NaN          20830169,37
# 11932                  NaN              NaN          20830169,37
# 11933                  NaN              NaN          20830169,37
# 11934                  NaN              NaN          20830169,37
# 11936                  NaN              NaN          20830169,37
# 11938                  NaN              NaN          20830169,37
# 11939                  NaN              NaN          20830169,37
#
#       valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 984                       3186059,50             1148899,50
# 985                       3186059,50              311400,00
# 4161                      2853400,00             2500000,00
# 11923                     9648900,84                8490,00
# 11927                     9648900,84                5499,50
# 11929                     9648900,84               35000,00
# 11932                     9648900,84               36500,00
# 11933                     9648900,84               43750,00
# 11934                     9648900,84               29500,00
# 11936                     9648900,84               16500,00
# 11938                     9648900,84               26700,00
# 11939                     9648900,84               25600,00
#
#       data_aberturaproposta data_ultimafaseprocesso
# 984     2013-10-04 10:00:00              2013-11-14
# 985     2013-10-04 10:00:00              2013-11-14
# 4161    2015-06-29 10:00:00              2015-08-17
# 11923   2020-03-30 10:00:00              2021-01-13
# 11927   2020-03-30 10:00:00              2021-01-13
# 11929   2020-03-30 10:00:00              2021-01-13
# 11932   2020-03-30 10:00:00              2021-01-13
# 11933   2020-03-30 10:00:00              2021-01-13
# 11934   2020-03-30 10:00:00              2021-01-13
# 11936   2020-03-30 10:00:00              2021-01-13
# 11938   2020-03-30 10:00:00              2021-01-13
# 11939   2020-03-30 10:00:00              2021-01-13
#
# [12 rows x 23 columns]

# %%
base[base.bairro_endcontratado.isnull()]
# Out:
#                                       comissao_licitacao  \
# 984    COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 985    COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 4161   COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 9457              COMISSÃO ESPECIAL DE LICITAÇÃO - GABPE
# 10850  COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS -...
# 11237             COMISSÃO ESPECIAL DE LICITAÇÃO - GABPE
# 11923                          EQUIPE DE PREGÃO - EMLURB
# 11927                          EQUIPE DE PREGÃO - EMLURB
# 11929                          EQUIPE DE PREGÃO - EMLURB
# 11932                          EQUIPE DE PREGÃO - EMLURB
# 11933                          EQUIPE DE PREGÃO - EMLURB
# 11934                          EQUIPE DE PREGÃO - EMLURB
# 11936                          EQUIPE DE PREGÃO - EMLURB
# 11938                          EQUIPE DE PREGÃO - EMLURB
# 11939                          EQUIPE DE PREGÃO - EMLURB
# 11979                          EQUIPE DE PREGÃO - EMLURB
# 11985                          EQUIPE DE PREGÃO - EMLURB
# 11989                          EQUIPE DE PREGÃO - EMLURB
# 12049                          EQUIPE DE PREGÃO - EMLURB
# 12055                          EQUIPE DE PREGÃO - EMLURB
# 12059                          EQUIPE DE PREGÃO - EMLURB
# 12060                          EQUIPE DE PREGÃO - EMLURB
# 12199              COMISSÃO ESPECIAL DE LICITAÇÃO - FCCR
# 12213             COMISSÃO ESPECIAL DE LICITAÇÃO - GABPE
# 12637  COMISSÃO PERMANENTE DE LICITAÇÃO DE MATERIAIS ...
#
REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11927  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11929  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11932  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11933  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11934  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11936  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11938  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11939  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11979  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 11985  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 11989  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 12049  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 12055  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 12059  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 12060  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  25356337000167.0
# 12199  CONSTITUI COMO OBJETO CONFECCAO DE CAMISAS EM ...  24728467000110.0
# 12213  CONTRATACAO DE EMPRESA ESPECIALIZADA PARA FORN...   4855314000127.0
# 12637  REGISTRO DE PRECOS COM VALIDADE DE 12   DOZE  ...  15786607000116.0
# 13974  REGISTRO DE PRECO COM VALIDADE 12 MESES PARA A...  29616156000183.0
# 14090  REALIZAR POR MEIO DE EDITAL A SELECAO DE 10 AC...  12728448000105.0
# 14237  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 14238  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 14241  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 16487  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 16488  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 17330  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
# 17331  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
# 17332  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
# 17333  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
# 17334  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
# 17335  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  84972926000139.0
#
#        ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 984    ...               NaN                NaN                  NaN
# 985    ...               NaN                NaN                  NaN
# 4161   ...               NaN                NaN                  NaN
# 9457   ...              31.0                NaN                  NaN
# 10850  ...            1825.0                301                  NaN
# 11237  ...              31.0                NaN                  NaN
# 11923  ...             699.0            BLOCO A                  NaN
# 11927  ...             699.0            BLOCO A                  NaN
# 11929  ...             699.0            BLOCO A                  NaN
# 11932  ...             699.0            BLOCO A                  NaN
# 11933  ...             699.0            BLOCO A                  NaN
# 11934  ...             699.0            BLOCO A                  NaN
# 11936  ...             699.0            BLOCO A                  NaN
# 11938  ...             699.0            BLOCO A                  NaN
# 11939  ...             699.0            BLOCO A                  NaN
# 11979  ...             113.0                NaN                  NaN
# 11985  ...             113.0                NaN                  NaN
# 11989  ...             113.0                NaN                  NaN
# 12049  ...             113.0                NaN                  NaN
# 12055  ...             113.0                NaN                  NaN
# 12059  ...             113.0                NaN                  NaN
# 12060  ...             113.0                NaN                  NaN
# 12199  ...              44.0                NaN                  NaN
# 12213  ...              31.0                NaN                  NaN
# 12637  ...             592.0             SALA 1                  NaN
# 13974  ...             320.0   1º ANDAR SALA 03                  NaN
# 14090  ...               NaN                NaN                  NaN
# 14237  ...            2965.0                NaN                  NaN
# 14238  ...            2965.0                NaN                  NaN
# 14241  ...            2965.0                NaN                  NaN
# 16487  ...            2965.0                NaN                  NaN
# 16488  ...            2965.0                NaN                  NaN
# 17330  ...             251.0                NaN                  NaN
# 17331  ...             251.0                NaN                  NaN
# 17332  ...             251.0                NaN                  NaN
# 17333  ...             251.0                NaN                  NaN
# 17334  ...             251.0                NaN                  NaN
# 17335  ...             251.0                NaN                  NaN
#
#       cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 984                    NaN              NaN           9207876,50
# 985                    NaN              NaN           9207876,50
# 4161                   NaN              NaN           2930322,00
# 9457               NITEROI               RJ           6005480,21
# 10850       BELO HORIZONTE              NaN           4874616,00
# 11237              NITEROI               RJ            333267,56
# 11923                  NaN              NaN          20830169,37
# 11927                  NaN              NaN          20830169,37
# 11929                  NaN              NaN          20830169,37
# 11932                  NaN              NaN          20830169,37
# 11933                  NaN              NaN          20830169,37
# 11934                  NaN              NaN          20830169,37
# 11936                  NaN              NaN          20830169,37
# 11938                  NaN              NaN          20830169,37
# 11939                  NaN              NaN          20830169,37
# 11979               MORENO               PE          20830169,37
# 11985               MORENO               PE          20830169,37
# 11989               MORENO               PE          20830169,37
# 12049               MORENO               PE          20830169,37
# 12055               MORENO               PE          20830169,37
# 12059               MORENO               PE          20830169,37
# 12060               MORENO               PE          20830169,37
# 12199    BRAGANÇA PAULISTA               SP            266550,00
# 12213              NITEROI               RJ            307590,49
# 12637           CAFELÂNDIA               SP             61296,25
# 13974              BARUERI               SP            926300,00
# 14090        CAXIAS DO SUL              NaN           1002000,00
# 14237               RECIFE               PE          21202161,70
# 14238               RECIFE               PE          21202161,70
# 14241               RECIFE               PE          21202161,70
# 16487               RECIFE               PE           8284746,65
# 16488               RECIFE               PE           8284746,65
# 17330                CAMBÉ               PR            893574,44
# 17331                CAMBÉ               PR            893574,44
# 17332                CAMBÉ               PR            893574,44
# 17333                CAMBÉ               PR            893574,44
# 17334                CAMBÉ               PR            893574,44
# 17335                CAMBÉ               PR            893574,44
#
#       valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 984                       3186059,50             1148899,50
# 985                       3186059,50              311400,00
# 4161                      2853400,00             2500000,00
# 9457                      4850725,96             4850725,96
# 10850                     4599972,00             4599972,00
# 11237                      330000,00              330000,00
# 11923                     9648900,84                8490,00
# 11927                     9648900,84                5499,50
# 11929                     9648900,84               35000,00
# 11932                     9648900,84               36500,00
# 11933                     9648900,84               43750,00
# 11934                     9648900,84               29500,00
# 11936                     9648900,84               16500,00
# 11938                     9648900,84               26700,00
# 11939                     9648900,84               25600,00
# 11979                     9648900,84               38500,00
# 11985                     9648900,84               14500,00
# 11989                     9648900,84               25000,00
# 12049                     9648900,84              109995,00
# 12055                     9648900,84              115999,50
# 12059                     9648900,84               38999,98
# 12060                     9648900,84               69000,00
# 12199                      243750,00              243750,00
# 12213                      260000,00              260000,00
# 12637                       19255,00                3200,00
# 13974                      744925,00              544950,00
# 15105  REGISTRO DE PRECO COM VALIDADE DE 12  DOZE  ME...  40820216000118.0
# 15106  REGISTRO DE PRECO COM VALIDADE DE 12  DOZE  ME...  40820216000118.0
# 15107  REGISTRO DE PRECO COM VALIDADE DE 12  DOZE  ME...  40820216000118.0
# 17953  REGISTRO DE PRECOS. PELO PERIODO DE 12  DOZE  ...  40820216000118.0
# 17957  REGISTRO DE PRECOS. PELO PERIODO DE 12  DOZE  ...  40820216000118.0
# 17963  REGISTRO DE PRECOS. PELO PERIODO DE 12  DOZE  ...  40820216000118.0
# 18424  REGISTRO DE PRECOS. COM VALIDADE DE 12  DOZE  ...  24789180000109.0
#
#        ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 984    ...               NaN                NaN                  NaN
# 985    ...               NaN                NaN                  NaN
# 4161   ...               NaN                NaN                  NaN
# 10850  ...            1825.0                301                  NaN
# 11923  ...             699.0            BLOCO A                  NaN
# 11927  ...             699.0            BLOCO A                  NaN
# 11929  ...             699.0            BLOCO A                  NaN
# 11932  ...             699.0            BLOCO A                  NaN
# 11933  ...             699.0            BLOCO A                  NaN
# 11934  ...             699.0            BLOCO A                  NaN
# 11936  ...             699.0            BLOCO A                  NaN
# 11938  ...             699.0            BLOCO A                  NaN
# 11939  ...             699.0            BLOCO A                  NaN
# 12182  ...              94.0                NaN         SANTO ALEIXO
# 13310  ...              13.0                NaN               CENTRO
# 13876  ...               NaN                NaN            DOS CASAS
# 14090  ...               NaN                NaN                  NaN
# 14639  ...              94.0                NaN         SANTO ALEIXO
# 14640  ...              94.0                NaN         SANTO ALEIXO
# 14641  ...              94.0                NaN         SANTO ALEIXO
# 14658  ...              68.0                  A               CENTRO
# 14992  ...              13.0                NaN               CENTRO
# 15105  ...              68.0                  A               CENTRO
# 15106  ...              68.0                  A               CENTRO
# 15107  ...              68.0                  A               CENTRO
# 17953  ...              68.0                  A               CENTRO
# 17957  ...              68.0                  A               CENTRO
# 17963  ...              68.0                  A               CENTRO
# 18424  ...              13.0                NaN               CENTRO
#
#           cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 984                        NaN              NaN           9207876,50
# 985                        NaN              NaN           9207876,50
# 4161                       NaN              NaN           2930322,00
# 10850           BELO HORIZONTE              NaN           4874616,00
# 11923                      NaN              NaN          20830169,37
# 11927                      NaN              NaN          20830169,37
# 11929                      NaN              NaN          20830169,37
# 11932                      NaN              NaN          20830169,37
# 11933                      NaN              NaN          20830169,37
# 11934                      NaN              NaN          20830169,37
# 11936                      NaN              NaN          20830169,37
# 11938                      NaN              NaN          20830169,37
# 11939                      NaN              NaN          20830169,37
# 12182  JABOATÃO DOS GUARARAPES              NaN           1223456,65
# 13310                    CAETÉ              NaN           1331464,85
# 13876             SÃO BERNARDO              NaN             64455,50
# 14090            CAXIAS DO SUL              NaN           1002000,00
# 14639  JABOATÃO DOS GUARARAPES              NaN            701203,01
# 14640  JABOATÃO DOS GUARARAPES              NaN            701203,01
# 14641  JABOATÃO DOS GUARARAPES              NaN            470539,40
# 14658                   GOIANA              NaN             46615,05
# 14992                    CAETÉ              NaN            652227,08
# 15105                   GOIANA              NaN             10008,94
# 15106                   GOIANA              NaN             10008,94
# 15107                   GOIANA              NaN             10008,94
# 17953                   GOIANA              NaN           1598559,93
# 17957                   GOIANA              NaN           1598559,93
# 17963                   GOIANA              NaN           1598559,93
# 18424                    CAETÉ              NaN            267000,00
#
#       valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 984                       3186059,50             1148899,50
# 985                       3186059,50              311400,00
# 4161                      2853400,00             2500000,00
# 10850                     4599972,00             4599972,00
# 11923                     9648900,84                8490,00
# 11927                     9648900,84                5499,50
# 11929                     9648900,84               35000,00
# 11932                     9648900,84               36500,00
# 11933                     9648900,84               43750,00
# 11934                     9648900,84               29500,00
# 11936                     9648900,84               16500,00
# 11938                     9648900,84               26700,00
# 11939                     9648900,84               25600,00
# 12182                      493303,08              493303,08
# 13310                      654216,00               75176,00
# 13876                       33300,00               33300,00
# 14090                      459000,00               45900,00
# 14639                      651321,62              394113,40
# 14640                      651321,62              257208,22
# 14641                      421845,92              421845,92
# 14658                       46500,00               46500,00
# 14992                      463799,80              133999,80
# 15105                        7214,40                 340,00
# 15106                        7214,40                 340,00
# 15107                        7214,40                 270,00
# 17953                     1315286,14               89294,94
# 17957                     1315286,14               21799,80
# 17963                     1315286,14               15000,00
# 18424                      216750,00               59250,00
#
#       data_aberturaproposta data_ultimafaseprocesso
# 984     2013-10-04 10:00:00              2013-11-14
# 985     2013-10-04 10:00:00              2013-11-14
# 4161    2015-06-29 10:00:00              2015-08-17
# 10850   2019-09-27 09:00:00              2020-02-17
# 11923   2020-03-30 10:00:00              2021-01-13
# 11927   2020-03-30 10:00:00              2021-01-13
# 11929   2020-03-30 10:00:00              2021-01-13
# 11932   2020-03-30 10:00:00              2021-01-13
# 11933   2020-03-30 10:00:00              2021-01-13
# 11934   2020-03-30 10:00:00              2021-01-13
# 11936   2020-03-30 10:00:00              2021-01-13
# 11938   2020-03-30 10:00:00              2021-01-13
# 11939   2020-03-30 10:00:00              2021-01-13
# 12182   2022-01-11 09:00:00              2022-01-22
# 13310   2022-09-21 09:00:00              2023-05-29
# 13876   2021-09-21 10:00:00              2021-11-05
# 14090   2021-05-17 11:00:00              2021-06-11
# 14639   2022-02-15 10:30:00              2022-04-08
# 14640   2022-02-15 10:30:00              2022-04-08
# 14641   2022-02-16 10:30:00              2022-04-13
# 14658   2022-05-30 10:30:00              2022-07-04
# 14992   2022-11-17 09:00:00              2023-03-17
# 15105   2023-01-12 09:00:00              2023-01-31
# 15106   2023-01-12 09:00:00              2023-01-31
# 15107   2023-01-12 09:00:00              2023-01-31
# 17953   2023-07-31 10:00:00              2023-09-19
# 17957   2023-07-31 10:00:00              2023-09-19
# 17963   2023-07-31 10:00:00              2023-09-19
# 18424   2023-10-03 09:00:00              2023-10-20
#
# [29 rows x 23 columns]

# %%
base['num_endcontratado'] = base['num_endcontratado'].fillna('S/N')

# %%
base['cpf_contratado'] = base['cpf_contratado'].fillna('Empresa')

# %%
base['cnpj_contratado'] = base['cnpj_contratado'].fillna('PF')

# %%
base[base.razao_nomecontratado == 'BECKMAN COULTER DO BRASIL LTDA']
# Out:
#                                     comissao_licitacao  \
# 984  COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
# 985  COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
#
#      ano_processolicitatorio  num_processolicitatorio  numero_lote  \
# 984                     2013                       15            1
# 985                     2013                       15            2
#
#     modalidadeprocessolicitatorio  numerolicitacaomodalidade  \
# 984             PREGÃO ELETRÔNICO                         12
# 985             PREGÃO ELETRÔNICO                         12
#
#      anolicitacaomodalidade           orgao_licitante  \
# 984                    2013  FUNDO MUNICIPAL DE SAUDE
# 985                    2013  FUNDO MUNICIPAL DE SAUDE
#
#                                                 objeto   cnpj_contratado  ...  \
# 984  AQUISIÇÃO DE TESTE HEMATOLÓGICOS BIOQUÍMICOS, ...  42160812000144.0  ...
# 985  AQUISIÇÃO DE TESTE HEMATOLÓGICOS BIOQUÍMICOS, ...  42160812000144.0  ...
#
#     num_endcontratado comp_endcontratado bairro_endcontratado  \
# 984               S/N                NaN                  NaN
# 985               S/N                NaN                  NaN
#
#     cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 984                  NaN              NaN           9207876,50
# 985                  NaN              NaN           9207876,50
#
#     valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 984                     3186059,50             1148899,50
# 985                     3186059,50              311400,00
#
#     data_aberturaproposta data_ultimafaseprocesso
# 984   2013-10-04 10:00:00              2013-11-14
# 985   2013-10-04 10:00:00              2013-11-14
#
# [2 rows x 23 columns]

# %% [markdown]
# Corrigindo empresa BECKMAN COULTER DO BRASIL LTDA

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'logradouro_endcontratado'] = 'Al. Rio Negro'

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'num_endcontratado'] = 500

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'comp_endcontratado'] = '15º andar'

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'cidade_endcontratado'] = 'Barueri'

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'uf_endcontratado'] = 'SP'

# %%
base.loc[base['razao_nomecontratado'] == 'BECKMAN COULTER DO BRASIL LTDA', 'bairro_endcontratado'] = 'Alphaville Industrial'

# %% [markdown]
# Corrigindo empresa FICAPOÇOS FIOS E CABOS LTDA.

# %% [markdown]
# http://cnpj.info/10376365000179

# %%
base[base.razao_nomecontratado == 'FICAPOÇOS FIOS E CABOS LTDA.']
# Out:
#               comissao_licitacao  ano_processolicitatorio  \
# 11923  EQUIPE DE PREGÃO - EMLURB                     2020
# 11927  EQUIPE DE PREGÃO - EMLURB                     2020
# 11929  EQUIPE DE PREGÃO - EMLURB                     2020
# 11932  EQUIPE DE PREGÃO - EMLURB                     2020
# 11933  EQUIPE DE PREGÃO - EMLURB                     2020
# 11934  EQUIPE DE PREGÃO - EMLURB                     2020
# 11936  EQUIPE DE PREGÃO - EMLURB                     2020
# 11938  EQUIPE DE PREGÃO - EMLURB                     2020
# 11939  EQUIPE DE PREGÃO - EMLURB                     2020
#
#        num_processolicitatorio  numero_lote modalidadeprocessolicitatorio  \
# 11923                        2            4             PREGÃO ELETRÔNICO
# 11927                        2            8             PREGÃO ELETRÔNICO
# 11929                        2           10             PREGÃO ELETRÔNICO
# 11932                        2           13             PREGÃO ELETRÔNICO
# 11933                        2           14             PREGÃO ELETRÔNICO
# 11934                        2           15             PREGÃO ELETRÔNICO
# 11936                        2           17             PREGÃO ELETRÔNICO
# 11938                        2           19             PREGÃO ELETRÔNICO
# 11939                        2           20             PREGÃO ELETRÔNICO
#
#        numerolicitacaomodalidade  anolicitacaomodalidade  \
# 11923                          2                    2020
# 11927                          2                    2020
# 11929                          2                    2020
# 11932                          2                    2020
# 11933                          2                    2020
# 11934                          2                    2020
# 11936                          2                    2020
# 11938                          2                    2020
# 11939                          2                    2020
#
#                                          orgao_licitante  \
# 11923  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11927  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11929  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11932  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11933  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11934  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11936  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11938  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 11939  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
#
#                                                   objeto   cnpj_contratado  \
# 11923  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11927  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11929  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11932  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11933  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11934  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11936  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11938  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
# 11939  REGISTRO DE PREÇOS, PARA AQUISIÇÃO DE MATERIAI...  10376365000179.0
#
#        ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 11923  ...             699.0            BLOCO A                  NaN
# 11927  ...             699.0            BLOCO A                  NaN
# 11929  ...             699.0            BLOCO A                  NaN
# 11932  ...             699.0            BLOCO A                  NaN
# 11933  ...             699.0            BLOCO A                  NaN
# 11934  ...             699.0            BLOCO A                  NaN
# 11936  ...             699.0            BLOCO A                  NaN
# 11938  ...             699.0            BLOCO A                  NaN
# 11939  ...             699.0            BLOCO A                  NaN
#
#       cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 11923                  NaN              NaN          20830169,37
# 11927                  NaN              NaN          20830169,37
# 11929                  NaN              NaN          20830169,37
# 11932                  NaN              NaN          20830169,37
# 11933                  NaN              NaN          20830169,37
# 11934                  NaN              NaN          20830169,37
# 11936                  NaN              NaN          20830169,37
# 11938                  NaN              NaN          20830169,37
# 11939                  NaN              NaN          20830169,37
#
#       valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 11923                     9648900,84                8490,00
# 11927                     9648900,84                5499,50
# 11929                     9648900,84               35000,00
# 11932                     9648900,84               36500,00
# 11933                     9648900,84               43750,00
# 11934                     9648900,84               29500,00
# 11936                     9648900,84               16500,00
# 11938                     9648900,84               26700,00
# 11939                     9648900,84               25600,00
#
#       data_aberturaproposta data_ultimafaseprocesso
# 11923   2020-03-30 10:00:00              2021-01-13
# 11927   2020-03-30 10:00:00              2021-01-13
# 11929   2020-03-30 10:00:00              2021-01-13
# 11932   2020-03-30 10:00:00              2021-01-13
# 11933   2020-03-30 10:00:00              2021-01-13
# 11934   2020-03-30 10:00:00              2021-01-13
# 11936   2020-03-30 10:00:00              2021-01-13
# 11938   2020-03-30 10:00:00              2021-01-13
# 11939   2020-03-30 10:00:00              2021-01-13
#
# [9 rows x 23 columns]

# %%
base.loc[base['razao_nomecontratado'] == 'FICAPOÇOS FIOS E CABOS LTDA.', 'logradouro_endcontratado'] = 'RUA UM'

# %%
base.loc[base['razao_nomecontratado'] == 'FICAPOÇOS FIOS E CABOS LTDA.', 'bairro_endcontratado'] = 'DISTRITO INDUSTRIAL'

# %%
base.loc[base['razao_nomecontratado'] == 'FICAPOÇOS FIOS E CABOS LTDA.', 'cidade_endcontratado'] = 'POCOS DE CALDAS'

# %%
base.loc[base['razao_nomecontratado'] == 'FICAPOÇOS FIOS E CABOS LTDA.', 'uf_endcontratado'] = 'MG'

# %% [markdown]
# Corrigindo empresa STEMAC SA GRUPOS GERADORES

# %% [markdown]
# http://cnpj.info/Stemac-Sa-Grupos-Geradores-Em-Recuperacao-Judicial-Anchieta-Porto-Alegre

# %%
base[base.razao_nomecontratado == 'STEMAC SA GRUPOS GERADORES']
# Out:
#                                      comissao_licitacao  \
# 4161  COMISSÃO PERMANENTE DE LICITAÇÃO DE SERVIÇOS D...
#
#       ano_processolicitatorio  num_processolicitatorio  numero_lote  \
# 4161                     2015                       17            2
#
#      modalidadeprocessolicitatorio  numerolicitacaomodalidade  \
# 4161             PREGÃO ELETRÔNICO                         12
#
#       anolicitacaomodalidade           orgao_licitante  \
# 4161                    2015  FUNDO MUNICIPAL DE SAUDE
#
#                                                  objeto   cnpj_contratado  \
# 4161  REGISTRO DE PREÇOS PARA AQUISIÇÃO DE GRUPOS GE...  92753268005262.0
#
#       ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 4161  ...               S/N                NaN                  NaN
#
#      cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 4161                  NaN              NaN           2930322,00
#
#      valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 4161                     2853400,00             2500000,00
#
#      data_aberturaproposta data_ultimafaseprocesso
# 4161   2015-06-29 10:00:00              2015-08-17
#
# [1 rows x 23 columns]

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'logradouro_endcontratado'] = 'AVENIDA SEVERO DULLIUS'

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'bairro_endcontratado'] = 'ANCHIETA'

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'cidade_endcontratado'] = 'PORTO ALEGRE'

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'uf_endcontratado'] = 'RS'

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'comp_endcontratado'] = 'Sala 1101-2'

# %%
base.loc[base['razao_nomecontratado'] == 'STEMAC SA GRUPOS GERADORES', 'num_endcontratado'] = 1395

# %% [markdown]
# Corrigindo empresa FML TECNOLOGIA ELETRONICA - EIRELI

# %% [markdown]
# http://cnpj.info/Fml-Tecnologia-Eletronica-Eireli-Fml-Tecnologia

# %%
base[base.razao_nomecontratado == 'FML TECNOLOGIA ELETRONICA - EIRELI']
# Out:
#               comissao_licitacao  ano_processolicitatorio  \
# 14237  EQUIPE DE PREGÃO - EMLURB                     2021
# 14238  EQUIPE DE PREGÃO - EMLURB                     2021
# 14241  EQUIPE DE PREGÃO - EMLURB                     2021
# 16487  EQUIPE DE PREGÃO - EMLURB                     2022
# 16488  EQUIPE DE PREGÃO - EMLURB                     2022
#
#        num_processolicitatorio  numero_lote modalidadeprocessolicitatorio  \
# 14237                       11            5             PREGÃO ELETRÔNICO
# 14238                       11            6             PREGÃO ELETRÔNICO
# 14241                       11            9             PREGÃO ELETRÔNICO
# 16487                       11            4             PREGÃO ELETRÔNICO
# 16488                       11            5             PREGÃO ELETRÔNICO
#
#        numerolicitacaomodalidade  anolicitacaomodalidade  \
# 14237                         11                    2021
# 14238                         11                    2021
# 14241                         11                    2021
# 16487                         11                    2022
# 16488                         11                    2022
#
#                                          orgao_licitante  \
# 14237  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 14238  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 14241  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 16487  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
# 16488  AUTARQUIA DE MANUTENCAO E LIMPEZA URBANA - EMLURB
#
#                                                   objeto   cnpj_contratado  \
# 14237  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 14238  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 14241  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 16487  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
# 16488  AQUISICAO DE LUMINARIAS E PROJETORES COM TECNO...  16981262000114.0
#
#        ... num_endcontratado comp_endcontratado bairro_endcontratado  \
# 14237  ...            2965.0                NaN                  NaN
# 14238  ...            2965.0                NaN                  NaN
# 14241  ...            2965.0                NaN                  NaN
# 16487  ...            2965.0                NaN                  NaN
# 16488  ...            2965.0                NaN                  NaN
#
#       cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 14237               RECIFE               PE          21202161,70
# 14238               RECIFE               PE          21202161,70
# 14241               RECIFE               PE          21202161,70
# 16487               RECIFE               PE           8284746,65
# 16488               RECIFE               PE           8284746,65
#
#       valor_totalhomologadolicitacao   valor_licitacao_lote  \
# 14237                     7836333,25               29499,75
# 14238                     7836333,25              382095,00
# 14241                     7836333,25              319999,50
# 16487                            NaN              149988,75
# 16488                            NaN              236250,00
#
#       data_aberturaproposta data_ultimafaseprocesso
# 14237   2021-06-10 09:30:00              2021-09-30
# 14238   2021-06-10 09:30:00              2021-09-30
# 14241   2021-06-10 09:30:00              2021-09-30
# 16487   2022-05-10 09:30:00              2022-12-30
# 16488   2022-05-10 09:30:00              2022-12-30
#
# [5 rows x 23 columns]

# %%
base.loc[base['razao_nomecontratado'] == 'FML TECNOLOGIA ELETRONICA - EIRELI', 'bairro_endcontratado'] = 'IBURA'

# %% [markdown]
# Corrigindo endereços por cidade

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA DA OLARIA', 'bairro_endcontratado'] = 'TORRÕES'

# %%
base.loc[base['cidade_endcontratado'] == 'BELO HORIZONTE', 'uf_endcontratado'] = 'MG'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA LINDOLFO DE AZEVEDO', 'bairro_endcontratado'] = 'JARDIM AMÉRICA'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA CLÉLIA MANFRO, 1843', 'logradouro_endcontratado'] = 'RUA CLÉLIA MANFRO'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA CLÉLIA MANFRO', 'num_endcontratado'] = '1843'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA BENJAMIN CONSTANT', 'bairro_endcontratado'] = 'LARGO DO BARRADAS'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA RUTH FRANCO ROCHA', 'bairro_endcontratado'] = 'SÃO LOURENÇO'

# %%
base.loc[base['logradouro_endcontratado'] == 'RUA CEL MAURÍCIO GONÇALVES MOREIRA', 'bairro_endcontratado'] = 'CENTRO'

# %%
base.loc[base['cidade_endcontratado'] == 'CAETÉ', 'uf_endcontratado'] = 'MG'

# %%
base.loc[base['cidade_endcontratado'] == 'GOIANA', 'uf_endcontratado'] = 'PE'

# %%
base.loc[base['cidade_endcontratado'] == 'JABOATÃO DOS GUARARAPES', 'uf_endcontratado'] = 'PE'

# %%
base.loc[base['cidade_endcontratado'] == 'SÃO BERNARDO', 'uf_endcontratado'] = 'SP'

# %%
base.loc[base['cidade_endcontratado'] == 'CAXIAS DO SUL', 'uf_endcontratado'] = 'RS'

# %% [markdown]
# Corrigindo empresa ARINOS COMÉRCIO DE MATERIAIS DE CONSTRUÇÃO LTDA

# %% [markdown]
# http://cnpj.info/29616156000183

# %%
base.loc[base['razao_nomecontratado'] == 'ARINOS COMÉRCIO DE MATERIAIS DE CONSTRUÇÃO LTDA', 'bairro_endcontratado'] = 'JARDIM FLORIDA'

# %% [markdown]
# Corrigindo empresa FOCO PRODUCOES LTDA

# %% [markdown]
# http://cnpj.info/Foco-Producoes-Foco-3-Producoes

# %%
base.loc[base['razao_nomecontratado'] == 'FOCO PRODUCOES LTDA', 'bairro_endcontratado'] = 'PETROPOLIS'

# %% [markdown]
# Corrigindo empresa JRIBEIRO COMERCIO ATACADISTA LDTA

# %% [markdown]
# http://cnpj.info/J-Ribeiro-Comercio-Atacadista-Ltda

# %%
base.loc[base['razao_nomecontratado'] == 'JRIBEIRO COMERCIO ATACADISTA LDTA', 'bairro_endcontratado'] = 'JARDIM BELA SUICA'

# %% [markdown]
# # Codificando os dados

# %%
base.columns
# Out:
# Index(['comissao_licitacao', 'ano_processolicitatorio',
#        'num_processolicitatorio', 'numero_lote',
#        'modalidadeprocessolicitatorio', 'numerolicitacaomodalidade',
#        'anolicitacaomodalidade', 'orgao_licitante', 'objeto',
#        'cnpj_contratado', 'cpf_contratado', 'razao_nomecontratado',
#        'logradouro_endcontratado', 'num_endcontratado', 'comp_endcontratado',
#        'bairro_endcontratado', 'cidade_endcontratado', 'uf_endcontratado',
#        'valor_total_estimado', 'valor_totalhomologadolicitacao',
#        'valor_licitacao_lote', 'data_aberturaproposta',
#        'data_ultimafaseprocesso'],
#       dtype='object')

# %%
label_encoder = LabelEncoder()
df_encoded = base.copy()
df_encoded.head()
# Out:
#                                   comissao_licitacao  ano_processolicitatorio  \
# 0  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
# 1  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
# 2  COMISSÃO PERMANENTE DE LICITAÇÃO DE EDUCAÇÃO -...                     2012
# 3  COMISSÃO PERMANENTE DE LICITAÇÃO DE MATERIAIS ...                     2012
# 4  COMISSÃO PERMANENTE DE LICITAÇÃO DE MATERIAIS ...                     2012
#
#    num_processolicitatorio  numero_lote modalidadeprocessolicitatorio  \
# 0                       29            1             PREGÃO ELETRÔNICO
# 1                       29            2             PREGÃO ELETRÔNICO
# 2                       30            1             PREGÃO ELETRÔNICO
# 3                       23            4             PREGÃO ELETRÔNICO
# 4                       23            5             PREGÃO ELETRÔNICO
#
#    numerolicitacaomodalidade  anolicitacaomodalidade  \
# 0                         27                    2012
# 1                         27                    2012
# 2                         28                    2012
# 3                         23                    2012
# 4                         23                    2012
#
#             orgao_licitante  \
# 0    SECRETARIA DE EDUCAÇÃO
# 1    SECRETARIA DE EDUCAÇÃO
# 2    SECRETARIA DE EDUCAÇÃO
# 3  FUNDO MUNICIPAL DE SAUDE
# 4  FUNDO MUNICIPAL DE SAUDE
#
#                                               objeto   cnpj_contratado  ...  \
# 0                                   MATERIAL GRÁFICO    758606000190.0  ...
# 1                                   MATERIAL GRÁFICO   7211171000109.0  ...
# 2                                AGENDA ESCOLAR 2013  13898993000102.0  ...
# 3  AQUISIÇÃO DE PNEUS, PARA ATENDER AS NECESSIDAD...  10511406000192.0  ...
# 4  AQUISIÇÃO DE PNEUS, PARA ATENDER AS NECESSIDAD...  10511406000192.0  ...
#
#   num_endcontratado comp_endcontratado  bairro_endcontratado  \
# 0             301.0                NaN              BULTRINS
# 1            5327.0                NaN              CANDEIAS
# 2               0.0           LOJA 005  CIDADE UNIVERSITARIA
# 3             810.0            LOJA 01              PRAZERES
# 4             810.0            LOJA 01              PRAZERES
#
#       cidade_endcontratado uf_endcontratado valor_total_estimado  \
# 0                   OLINDA               PE            333750,00
# 1  JABOATAO DOS GUARARAPES               PE            333750,00
# 2                   MACEIO               AL            530469,54
# 3  JABOATAO DOS GUARARAPES               PE             16870,35
# 4  JABOATAO DOS GUARARAPES               PE             16870,35
#
#   valor_totalhomologadolicitacao   valor_licitacao_lote data_aberturaproposta  \
# 0                       66358,00               15210,00   2012-12-20 10:00:00
# 1                       66358,00               51148,00   2012-12-20 10:00:00
# 2                      357895,02              357895,02   2013-01-02 10:00:00
# 3                        1518,00                 800,00   2012-12-19 11:00:00
# 4                        1518,00                 718,00   2012-12-19 11:00:00
#
#   data_ultimafaseprocesso
# 0              2013-01-07
# 1              2013-01-07
# 2              2013-01-09
# 3              2013-03-01
# 4              2013-03-01
#
# [5 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.
